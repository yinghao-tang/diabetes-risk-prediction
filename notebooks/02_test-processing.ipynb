# %%
import sys
import os

sys.path.append("../")

# %%
from src.data_processing import load_data, preprocess_data


df = load_data(
    "../data/raw/diabetes_risk_prediction_dataset.csv"
)


X_processed, y, preprocessor = preprocess_data(df)


print(X_processed.shape)

print(y.shape)
# Out:
# (50000, 57)
# (50000,)

# %%
import os

os.getcwd()
# Out:
# 'e:\\tool\\my_program\\diabetes-risk-prediction\\notebooks'
